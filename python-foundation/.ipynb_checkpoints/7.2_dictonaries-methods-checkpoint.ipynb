# %%
#Dictionaries
empty_dict = {}
d1 = { "host_name" : "SERVER01", 
       "CPUCORE" : 16,
        "RAM_USAGE" : [45, 56,78,89]
     }
d1
# Out:
# {'host_name': 'SERVER01', 'CPUCORE': 16, 'RAM_USAGE': [45, 56, 78, 89]}

# %%
d1["RAM_USAGE"]
# Out:
# [45, 56, 78, 89]

# %%
d1[5] = "check_points"

# %%
d1
# Out:
# {'host_name': 'SERVER01',
#  'CPUCORE': 16,
#  'RAM_USAGE': [45, 56, 78, 89],
#  5: 'check_points'}

# %%
d1["dummy_server"] = "SERVER00"

# %%
d1
# Out:
# {'host_name': 'SERVER01',
#  'CPUCORE': 16,
#  'RAM_USAGE': [45, 56, 78, 89],
#  5: 'check_points',
#  'dummy_server': 'SERVER00'}

# %%
#deleting  values using del or pop
del d1[5]

# %%
d1
# Out:
# {'host_name': 'SERVER01',
#  'CPUCORE': 16,
#  'RAM_USAGE': [45, 56, 78, 89],
#  'dummy_server': 'SERVER00'}

# %%
d1[5] =  "check points"
d1
# Out:
# {'host_name': 'SERVER01',
#  'CPUCORE': 16,
#  'RAM_USAGE': [45, 56, 78, 89],
#  'dummy_server': 'SERVER00',
#  5: 'check points'}

# %%
d1.pop(5)
# Out:
# 'check points'

# %%
d1
# Out:
# {'host_name': 'SERVER01',
#  'CPUCORE': 16,
#  'RAM_USAGE': [45, 56, 78, 89],
#  'dummy_server': 'SERVER00'}

# %%
list(d1.keys())
# Out:
# ['host_name', 'CPUCORE', 'RAM_USAGE', 'dummy_server']

# %%
list(d1.values())
# Out:
# ['SERVER01', 16, [45, 56, 78, 89], 'SERVER00']

# %%
list(d1.items())
# Out:
# [('host_name', 'SERVER01'),
#  ('CPUCORE', 16),
#  ('RAM_USAGE', [45, 56, 78, 89]),
#  ('dummy_server', 'SERVER00')]

# %%
#merging one dictionary into another
d1.update({"disk": 77})
d1
d1.pop('disk')
# Out:
# 77

# %%
d1
# Out:
# {'host_name': 'SERVER01',
#  'CPUCORE': 16,
#  'RAM_USAGE': [45, 56, 78, 89],
#  'dummy_server': 'SERVER00'}
