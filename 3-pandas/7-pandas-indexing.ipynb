# %%
# LOAD DATASETS
import pandas as pd
import numpy as np

# ── Load all three datasets ────────────────────────────────────────────
df_metrics = pd.read_csv(
    "server_metrics.csv",
    parse_dates=["timestamp"],
    dtype={"server_id": "category"},
    na_values=["N/A", "null", "—"]
)

df_tickets = pd.read_csv(
    "incidents.csv",
    parse_dates=["created_at", "resolved_at"]
)

df_logs = pd.read_csv(
    "app_logs.csv",
    parse_dates=["timestamp"]
)

# ── Confirm shapes ─────────────────────────────────────────────────────
print(f"df_metrics : {df_metrics.shape}")
print(f"df_tickets : {df_tickets.shape}")
print(f"df_logs    : {df_logs.shape}")
# Out:
# df_metrics : (525, 7)
# df_tickets : (213, 7)
# df_logs    : (315, 5)

# %%
print(df_metrics.index)
print(df_metrics.head(3))
# Out:
# RangeIndex(start=0, stop=525, step=1)
#    timestamp server_id  cpu_pct  memory_pct  response_ms  disk_pct status
# 0 2026-01-01    srv-01     49.6        94.6        891.8      68.9     ok
# 1 2026-01-01    srv-02     32.3        33.9       1046.1      69.1     ok
# 2 2026-01-01    srv-03     21.6        96.0       1007.3      43.8     ok

# %%
# Set_index() and reset_index()

# %%
# Set server_id as index
df_metrics_idx = df_metrics.set_index("server_id")
print(df_metrics_idx.head())
print(df_metrics_idx.index)
# Out:
#            timestamp  cpu_pct  memory_pct  response_ms  disk_pct status
# server_id
# srv-01    2026-01-01     49.6        94.6        891.8      68.9     ok
# srv-02    2026-01-01     32.3        33.9       1046.1      69.1     ok
# srv-03    2026-01-01     21.6        96.0       1007.3      43.8     ok
# srv-04    2026-01-01     34.5        50.7        653.5      58.1     ok
# srv-05    2026-01-01     68.3        39.5        386.0      53.8     ok
# CategoricalIndex(['srv-01', 'srv-02', 'srv-03', 'srv-04', 'srv-05', 'srv-01',
#                   'srv-02', 'srv-03', 'srv-04', 'srv-05',
#                   ...
#                   'srv-01', 'srv-02', 'srv-03', 'srv-04', 'srv-05', 'srv-01',
#                   'srv-02', 'srv-03', 'srv-04', 'srv-05'],
#                  categories=['srv-01', 'srv-02', 'srv-03', 'srv-04', 'srv-05'], ordered=False, dtype='category', name='server_id', length=525)

# %%
# Set timestamp as index — more useful for time series
df_metrics_ts = df_metrics.set_index("timestamp")
print(df_metrics_ts.head())
# Out:
#            server_id  cpu_pct  memory_pct  response_ms  disk_pct status
# timestamp
# 2026-01-01    srv-01     49.6        94.6        891.8      68.9     ok
# 2026-01-01    srv-02     32.3        33.9       1046.1      69.1     ok
# 2026-01-01    srv-03     21.6        96.0       1007.3      43.8     ok
# 2026-01-01    srv-04     34.5        50.7        653.5      58.1     ok
# 2026-01-01    srv-05     68.3        39.5        386.0      53.8     ok

# %%
# Reset back to default integer index
df_metrics_reset = df_metrics_ts.reset_index()
print(df_metrics_reset.head())
print(df_metrics_reset.index)
# Out:
#    timestamp server_id  cpu_pct  memory_pct  response_ms  disk_pct status
# 0 2026-01-01    srv-01     49.6        94.6        891.8      68.9     ok
# 1 2026-01-01    srv-02     32.3        33.9       1046.1      69.1     ok
# 2 2026-01-01    srv-03     21.6        96.0       1007.3      43.8     ok
# 3 2026-01-01    srv-04     34.5        50.7        653.5      58.1     ok
# 4 2026-01-01    srv-05     68.3        39.5        386.0      53.8     ok
# RangeIndex(start=0, stop=525, step=1)

# %%
# loc[] vs iloc[]

# %%
# loc — label based (use index values)
df_metrics_ts = df_metrics.set_index("timestamp")

# Get all rows for a specific date
print(df_metrics_ts.loc["2026-01-01"])
# Out:
#                     server_id  cpu_pct  memory_pct  response_ms  disk_pct  \
# timestamp
# 2026-01-01 00:00:00    srv-01     49.6        94.6        891.8      68.9
# 2026-01-01 00:00:00    srv-02     32.3        33.9       1046.1      69.1
# 2026-01-01 00:00:00    srv-03     21.6        96.0       1007.3      43.8
# 2026-01-01 00:00:00    srv-04     34.5        50.7        653.5      58.1
# 2026-01-01 00:00:00    srv-05     68.3        39.5        386.0      53.8
# ...                       ...      ...         ...          ...       ...
# 2026-01-01 04:00:00    srv-01     22.5        73.3        411.5      63.1
# 2026-01-01 04:00:00    srv-02     39.7        57.9        918.9      44.9
# 2026-01-01 04:00:00    srv-03     42.9        41.0       1119.2      82.5
# 2026-01-01 04:00:00    srv-04     88.8        84.6        264.6      88.0
# 2026-01-01 04:00:00    srv-05     83.8        90.9        415.7      37.2
#
#                       status
# timestamp
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# ...                      ...
# 2026-01-01 04:00:00  warning
# 2026-01-01 04:00:00       ok
# 2026-01-01 04:00:00       ok
# 2026-01-01 04:00:00       ok
# 2026-01-01 04:00:00       ok
#
# [145 rows x 6 columns]

# %%
# loc — label based (use index values)
df_metrics_ts = df_metrics.set_index("timestamp")

# Get all rows for a specific date
print(df_metrics_ts.loc["2026-01-01"])
# Out:
#                     server_id  cpu_pct  memory_pct  response_ms  disk_pct  \
# timestamp
# 2026-01-01 00:00:00    srv-01     49.6        94.6        891.8      68.9
# 2026-01-01 00:00:00    srv-02     32.3        33.9       1046.1      69.1
# 2026-01-01 00:00:00    srv-03     21.6        96.0       1007.3      43.8
# 2026-01-01 00:00:00    srv-04     34.5        50.7        653.5      58.1
# 2026-01-01 00:00:00    srv-05     68.3        39.5        386.0      53.8
# ...                       ...      ...         ...          ...       ...
# 2026-01-01 04:00:00    srv-01     22.5        73.3        411.5      63.1
# 2026-01-01 04:00:00    srv-02     39.7        57.9        918.9      44.9
# 2026-01-01 04:00:00    srv-03     42.9        41.0       1119.2      82.5
# 2026-01-01 04:00:00    srv-04     88.8        84.6        264.6      88.0
# 2026-01-01 04:00:00    srv-05     83.8        90.9        415.7      37.2
#
#                       status
# timestamp
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# 2026-01-01 00:00:00       ok
# ...                      ...
# 2026-01-01 04:00:00  warning
# 2026-01-01 04:00:00       ok
# 2026-01-01 04:00:00       ok
# 2026-01-01 04:00:00       ok
# 2026-01-01 04:00:00       ok
#
# [145 rows x 6 columns]

# %%
df_metrics.iloc[0:3]      # first 3 rows
df_metrics.iloc[-3:]      # last 3 rows
df_metrics.iloc[0, 2]     # single value — row 0, column 2
# Out:
# np.float64(49.6)

# %%
# MultiIndex

# %%
# Set server_id + timestamp as MultiIndex
df_multi = df_metrics.set_index(["server_id", "timestamp"])
print(df_multi.head(10))
print(df_multi.index)
# Out:
#                                cpu_pct  memory_pct  response_ms  disk_pct  \
# server_id timestamp
# srv-01    2026-01-01 00:00:00     49.6        94.6        891.8      68.9
# srv-02    2026-01-01 00:00:00     32.3        33.9       1046.1      69.1
# srv-03    2026-01-01 00:00:00     21.6        96.0       1007.3      43.8
# srv-04    2026-01-01 00:00:00     34.5        50.7        653.5      58.1
# srv-05    2026-01-01 00:00:00     68.3        39.5        386.0      53.8
# srv-01    2026-01-01 01:00:00     82.0        43.6        641.4      68.5
# srv-02    2026-01-01 01:00:00     68.0        41.6        124.8      91.7
# srv-03    2026-01-01 01:00:00     83.9        50.7        162.3      74.5
# srv-04    2026-01-01 01:00:00     29.6        63.7         89.5      89.1
# srv-05    2026-01-01 01:00:00     72.3        51.2        648.1      65.5
#
#                                  status
# server_id timestamp
# srv-01    2026-01-01 00:00:00        ok
# srv-02    2026-01-01 00:00:00        ok
# srv-03    2026-01-01 00:00:00        ok
# srv-04    2026-01-01 00:00:00        ok
# srv-05    2026-01-01 00:00:00        ok
# srv-01    2026-01-01 01:00:00        ok
# srv-02    2026-01-01 01:00:00  critical
# srv-03    2026-01-01 01:00:00        ok
# srv-04    2026-01-01 01:00:00        ok
# srv-05    2026-01-01 01:00:00        ok
# MultiIndex([('srv-01', '2026-01-01 00:00:00'),
#             ('srv-02', '2026-01-01 00:00:00'),
#             ('srv-03', '2026-01-01 00:00:00'),
#             ('srv-04', '2026-01-01 00:00:00'),
#             ('srv-05', '2026-01-01 00:00:00'),
#             ('srv-01', '2026-01-01 01:00:00'),
#             ('srv-02', '2026-01-01 01:00:00'),
#             ('srv-03', '2026-01-01 01:00:00'),
#             ('srv-04', '2026-01-01 01:00:00'),
#             ('srv-05', '2026-01-01 01:00:00'),
#             ...
#             ('srv-01', '2026-01-01 03:00:00'),
#             ('srv-02', '2026-01-01 03:00:00'),
#             ('srv-03', '2026-01-01 03:00:00'),
#             ('srv-04', '2026-01-01 03:00:00'),
#             ('srv-05', '2026-01-01 03:00:00'),
#             ('srv-01', '2026-01-01 04:00:00'),
#             ('srv-02', '2026-01-01 04:00:00'),
#             ('srv-03', '2026-01-01 04:00:00'),
#             ('srv-04', '2026-01-01 04:00:00'),
#             ('srv-05', '2026-01-01 04:00:00')],
#            names=['server_id', 'timestamp'], length=525)

# %%
# Slice by outer index — all rows for srv-01
print(df_multi.loc["srv-01"])
# Out:
#                      cpu_pct  memory_pct  response_ms  disk_pct   status
# timestamp
# 2026-01-01 00:00:00     49.6        94.6        891.8      68.9       ok
# 2026-01-01 01:00:00     82.0        43.6        641.4      68.5       ok
# 2026-01-01 02:00:00     96.6        82.7       1130.4      88.2       ok
# 2026-01-01 03:00:00     77.6        82.4        135.2      53.3       ok
# 2026-01-01 04:00:00     22.5        73.3        411.5      63.1  warning
# ...                      ...         ...          ...       ...      ...
# 2026-01-01 00:00:00     49.6        94.6        891.8      68.9       ok
# 2026-01-01 01:00:00     82.0        43.6        641.4      68.5       ok
# 2026-01-01 02:00:00     96.6        82.7       1130.4      88.2       ok
# 2026-01-01 03:00:00     77.6        82.4        135.2      53.3       ok
# 2026-01-01 04:00:00     22.5        73.3        411.5      63.1  warning
#
# [105 rows x 5 columns]

# %%
# Slice by outer + inner index — srv-01 on specific date
print(df_multi.loc[("srv-01", "2026-01-01")])

df_multi = df_metrics.set_index(["server_id", "timestamp"]).sort_index()

# Now slice cleanly — no warning
print(df_multi.loc["srv-01"])
print(df_multi.loc[("srv-01", "2026-01-01")])
# Out:
#                      cpu_pct  memory_pct  response_ms  disk_pct   status
# timestamp
# 2026-01-01 00:00:00     49.6        94.6        891.8      68.9       ok
# 2026-01-01 00:00:00     49.6        94.6        891.8      68.9       ok
# 2026-01-01 01:00:00     82.0        43.6        641.4      68.5       ok
# 2026-01-01 01:00:00     82.0        43.6        641.4      68.5       ok
# 2026-01-01 02:00:00     96.6        82.7       1130.4      88.2       ok
# ...                      ...         ...          ...       ...      ...
# 2026-01-04 23:00:00     41.8        50.8        957.3      59.0  warning
# 2026-01-05 00:00:00     46.9        34.9        521.1      50.2       ok
# 2026-01-05 01:00:00     91.1        37.9       1149.3      50.4  warning
# 2026-01-05 02:00:00     41.3        95.7        691.4      52.6       ok
# 2026-01-05 03:00:00     88.7        38.9        959.1      38.1  warning
#
# [105 rows x 5 columns]
#             cpu_pct  memory_pct  response_ms  disk_pct status
# timestamp
# 2026-01-01     49.6        94.6        891.8      68.9     ok
# 2026-01-01     49.6        94.6        891.8      68.9     ok

# %%
# sort_index()
# Sort by index ascending (default)
df_metrics_ts = df_metrics.set_index("timestamp").sort_index()
print(df_metrics_ts.head())

# Sort descending — latest readings first
print(df_metrics_ts.sort_index(ascending=False).head())
# Out:
#            server_id  cpu_pct  memory_pct  response_ms  disk_pct status
# timestamp
# 2026-01-01    srv-01     49.6        94.6        891.8      68.9     ok
# 2026-01-01    srv-03     21.6        96.0       1007.3      43.8     ok
# 2026-01-01    srv-01     49.6        94.6        891.8      68.9     ok
# 2026-01-01    srv-02     32.3        33.9       1046.1      69.1     ok
# 2026-01-01    srv-05     68.3        39.5        386.0      53.8     ok
#                     server_id  cpu_pct  memory_pct  response_ms  disk_pct  \
# timestamp
# 2026-01-05 03:00:00    srv-04     42.6        43.8        926.1      55.1
# 2026-01-05 03:00:00    srv-05     58.9        69.3       1045.4      93.7
# 2026-01-05 03:00:00    srv-03     97.5        62.9       1043.1      68.3
# 2026-01-05 03:00:00    srv-02     41.8        89.6       1135.6      39.7
# 2026-01-05 03:00:00    srv-01     88.7        38.9        959.1      38.1
#
#                       status
# timestamp
# 2026-01-05 03:00:00       ok
# 2026-01-05 03:00:00       ok
# 2026-01-05 03:00:00       ok
# 2026-01-05 03:00:00       ok
# 2026-01-05 03:00:00  warning

# %%
# index based vs boolean filtering
# Boolean filter — verbose
df_metrics[
    (df_metrics["server_id"] == "srv-01") &
    (df_metrics["timestamp"] >= "2026-01-01") &
    (df_metrics["timestamp"] <= "2026-01-03")
]

# Index-based — clean
df_multi = df_metrics.set_index(["server_id", "timestamp"]).sort_index()
df_multi.loc["srv-01", "2026-01-01":"2026-01-03"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2026-01-01'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 11
#       9 # Index-based — clean
#      10 df_multi = df_metrics.set_index(["server_id", "timestamp"]).sort_index()
# ---> 11 df_multi.loc["srv-01", "2026-01-01":"2026-01-03"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1369, in _LocIndexer._getitem_tuple(self, tup)
#    1367 with suppress(IndexingError):
#    1368     tup = self._expand_ellipsis(tup)
# -> 1369     return self._getitem_lowerdim(tup)
#    1371 # no multi-index, so validate all of the indexers
#    1372 tup = self._validate_tuple_indexer(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1042, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1040 # we may have a nested tuples indexer here
#    1041 if self._is_nested_tuple_indexer(tup):
# -> 1042     return self._getitem_nested_tuple(tup)
#    1044 # we maybe be using a tuple to represent multiple dimensions here
#    1045 ax0 = self.obj._get_axis(0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1154, in _LocationIndexer._getitem_nested_tuple(self, tup)
#    1151     axis -= 1
#    1152     continue
# -> 1154 obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#    1155 axis -= 1
#    1157 # if we have a scalar, we are done
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1412, in _LocIndexer._getitem_axis(self, key, axis)
#    1410 if isinstance(key, slice):
#    1411     self._validate_key(key, axis)
# -> 1412     return self._get_slice_axis(key, axis=axis)
#    1413 elif com.is_bool_indexer(key):
#    1414     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1444, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1441     return obj.copy(deep=False)
#    1443 labels = obj._get_axis(axis)
# -> 1444 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1446 if isinstance(indexer, slice):
#    1447     return self.obj._slice(indexer, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6708, in Index.slice_indexer(self, start, end, step)
#    6664 def slice_indexer(
#    6665     self,
#    6666     start: Hashable | None = None,
#    6667     end: Hashable | None = None,
#    6668     step: int | None = None,
#    6669 ) -> slice:
#    6670     """
#    6671     Compute the slice indexer for input labels and step.
#    6672
#    (...)   6706     slice(1, 3, None)
#    6707     """
# -> 6708     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6710     # return a slice
#    6711     if not is_scalar(start_slice):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.slice_locs(self, start, end, step)
#    6932 start_slice = None
#    6933 if start is not None:
# -> 6934     start_slice = self.get_slice_bound(start, "left")
#    6935 if start_slice is None:
#    6936     start_slice = 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6859, in Index.get_slice_bound(self, label, side)
#    6856         return self._searchsorted_monotonic(label, side)
#    6857     except ValueError:
#    6858         # raise the original KeyError
# -> 6859         raise err
#    6861 if isinstance(slc, np.ndarray):
#    6862     # get_loc may return a boolean array, which
#    6863     # is OK as long as they are representable by a slice.
#    6864     assert is_bool_dtype(slc.dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6853, in Index.get_slice_bound(self, label, side)
#    6851 # we need to look up the label
#    6852 try:
# -> 6853     slc = self.get_loc(label)
#    6854 except KeyError as err:
#    6855     try:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '2026-01-01'

# %%
# AIOps Pattern: Timestamp as Index

# %%
# Set timestamp as index for time-based slicing
df_metrics_ts = df_metrics.set_index("timestamp").sort_index()

# Get all readings between two timestamps
print(df_metrics_ts.loc["2026-01-01":"2026-01-03", ["server_id", "cpu_pct", "status"]])

# Get critical readings in a time window
print(df_metrics_ts.loc["2026-01-01":"2026-01-03"][
    df_metrics_ts.loc["2026-01-01":"2026-01-03"]["status"] == "critical"
])
# Out:
#                     server_id  cpu_pct   status
# timestamp
# 2026-01-01 00:00:00    srv-01     49.6       ok
# 2026-01-01 00:00:00    srv-03     21.6       ok
# 2026-01-01 00:00:00    srv-01     49.6       ok
# 2026-01-01 00:00:00    srv-02     32.3       ok
# 2026-01-01 00:00:00    srv-05     68.3       ok
# ...                       ...      ...      ...
# 2026-01-03 23:00:00    srv-01     44.9  warning
# 2026-01-03 23:00:00    srv-02     23.0       ok
# 2026-01-03 23:00:00    srv-04     31.9       ok
# 2026-01-03 23:00:00    srv-05     26.7       ok
# 2026-01-03 23:00:00    srv-03     90.7       ok
#
# [385 rows x 3 columns]
#                     server_id  cpu_pct  memory_pct  response_ms  disk_pct  \
# timestamp
# 2026-01-01 01:00:00    srv-02     68.0        41.6        124.8      91.7
# 2026-01-01 01:00:00    srv-02     68.0        41.6        124.8      91.7
# 2026-01-01 02:00:00    srv-04     62.9        39.6        972.5      34.8
# 2026-01-01 02:00:00    srv-04     62.9        39.6        972.5      34.8
# 2026-01-01 05:00:00    srv-03     45.5        65.3        858.5      53.6
# 2026-01-01 06:00:00    srv-01     91.8        46.3        216.6      61.8
# 2026-01-01 12:00:00    srv-05     63.4        78.6        809.2      48.2
# 2026-01-01 18:00:00    srv-03     29.3        74.1        908.0      67.9
# 2026-01-01 18:00:00    srv-04     49.6        49.4       1048.9      44.5
# 2026-01-01 19:00:00    srv-05     47.9        69.7        139.4      93.3
# 2026-01-02 18:00:00    srv-01     89.1        66.0       1129.9      81.9
# 2026-01-02 18:00:00    srv-05     43.4        45.9         98.4      31.2
# 2026-01-02 20:00:00    srv-01     24.6        95.9       1066.4      90.3
# 2026-01-03 00:00:00    srv-02     80.9        76.5        562.8      47.8
# 2026-01-03 04:00:00    srv-05     39.5        40.8       1052.6      44.2
# 2026-01-03 05:00:00    srv-02     63.9        78.9        312.7      94.8
# 2026-01-03 08:00:00    srv-05     45.0        64.5         97.8      39.6
# 2026-01-03 10:00:00    srv-03     51.1        74.3        172.6      72.8
# 2026-01-03 13:00:00    srv-04     76.0        37.3        702.4      46.7
# 2026-01-03 15:00:00    srv-02     38.3        56.6        733.6      62.3
# 2026-01-03 18:00:00    srv-03     67.4        65.1       1107.3      62.3
# 2026-01-03 22:00:00    srv-01     62.3        44.6         63.9      45.7
#
#                        status
# timestamp
# 2026-01-01 01:00:00  critical
# 2026-01-01 01:00:00  critical
# 2026-01-01 02:00:00  critical
# 2026-01-01 02:00:00  critical
# 2026-01-01 05:00:00  critical
# 2026-01-01 06:00:00  critical
# 2026-01-01 12:00:00  critical
# 2026-01-01 18:00:00  critical
# 2026-01-01 18:00:00  critical
# 2026-01-01 19:00:00  critical
# 2026-01-02 18:00:00  critical
# 2026-01-02 18:00:00  critical
# 2026-01-02 20:00:00  critical
# 2026-01-03 00:00:00  critical
# 2026-01-03 04:00:00  critical
# 2026-01-03 05:00:00  critical
# 2026-01-03 08:00:00  critical
# 2026-01-03 10:00:00  critical
# 2026-01-03 13:00:00  critical
# 2026-01-03 15:00:00  critical
# 2026-01-03 18:00:00  critical
# 2026-01-03 22:00:00  critical
